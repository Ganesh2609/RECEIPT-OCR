# %%
import torch 
from torch import nn 
from torchinfo import summary 
from Restformer import Restformer

# %%
model = Restformer().to('cuda')

summary(model=model,
        input_size=(4, 1, 400, 400),
        col_names=['input_size', 'output_size', 'num_params', 'trainable'],
        col_width=20,
        row_settings=['var_names'])
# Out:
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# Restformer (Restformer)                                      [4, 1, 400, 400]     [4, 1, 400, 400]     --                   True
# ├─Conv2d (initial_conv)                                      [4, 1, 400, 400]     [4, 48, 400, 400]    432                  True
# ├─Sequential (encoder1)                                      [4, 48, 400, 400]    [4, 48, 400, 400]    --                   True
# │    └─TransformerBlock (0)                                  [4, 48, 400, 400]    [4, 48, 400, 400]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 48, 400, 400]    [4, 48, 400, 400]    48                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 48, 400, 400]    [4, 48, 400, 400]    10,513               True
# │    │    └─LayerNorm (norm2)                                [4, 48, 400, 400]    [4, 48, 400, 400]    48                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 48, 400, 400]    [4, 48, 400, 400]    22,860               True
# │    └─TransformerBlock (1)                                  [4, 48, 400, 400]    [4, 48, 400, 400]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 48, 400, 400]    [4, 48, 400, 400]    48                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 48, 400, 400]    [4, 48, 400, 400]    10,513               True
# │    │    └─LayerNorm (norm2)                                [4, 48, 400, 400]    [4, 48, 400, 400]    48                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 48, 400, 400]    [4, 48, 400, 400]    22,860               True
# │    └─TransformerBlock (2)                                  [4, 48, 400, 400]    [4, 48, 400, 400]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 48, 400, 400]    [4, 48, 400, 400]    48                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 48, 400, 400]    [4, 48, 400, 400]    10,513               True
# │    │    └─LayerNorm (norm2)                                [4, 48, 400, 400]    [4, 48, 400, 400]    48                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 48, 400, 400]    [4, 48, 400, 400]    22,860               True
# │    └─TransformerBlock (3)                                  [4, 48, 400, 400]    [4, 48, 400, 400]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 48, 400, 400]    [4, 48, 400, 400]    48                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 48, 400, 400]    [4, 48, 400, 400]    10,513               True
# │    │    └─LayerNorm (norm2)                                [4, 48, 400, 400]    [4, 48, 400, 400]    48                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 48, 400, 400]    [4, 48, 400, 400]    22,860               True
# ├─Downsample (down1)                                         [4, 48, 400, 400]    [4, 96, 200, 200]    --                   True
# │    └─Sequential (layers)                                   [4, 48, 400, 400]    [4, 96, 200, 200]    --                   True
# │    │    └─Conv2d (0)                                       [4, 48, 400, 400]    [4, 24, 400, 400]    10,368               True
# │    │    └─PixelUnshuffle (1)                               [4, 24, 400, 400]    [4, 96, 200, 200]    --                   --
# ├─Sequential (encoder2)                                      [4, 96, 200, 200]    [4, 96, 200, 200]    --                   True
# │    └─TransformerBlock (0)                                  [4, 96, 200, 200]    [4, 96, 200, 200]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 200, 200]    [4, 96, 200, 200]    39,458               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 200, 200]    [4, 96, 200, 200]    82,620               True
# │    └─TransformerBlock (1)                                  [4, 96, 200, 200]    [4, 96, 200, 200]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 200, 200]    [4, 96, 200, 200]    39,458               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 200, 200]    [4, 96, 200, 200]    82,620               True
# │    └─TransformerBlock (2)                                  [4, 96, 200, 200]    [4, 96, 200, 200]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 200, 200]    [4, 96, 200, 200]    39,458               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 200, 200]    [4, 96, 200, 200]    82,620               True
# │    └─TransformerBlock (3)                                  [4, 96, 200, 200]    [4, 96, 200, 200]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 200, 200]    [4, 96, 200, 200]    39,458               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 200, 200]    [4, 96, 200, 200]    82,620               True
# │    └─TransformerBlock (4)                                  [4, 96, 200, 200]    [4, 96, 200, 200]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 200, 200]    [4, 96, 200, 200]    39,458               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 200, 200]    [4, 96, 200, 200]    82,620               True
# │    └─TransformerBlock (5)                                  [4, 96, 200, 200]    [4, 96, 200, 200]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 200, 200]    [4, 96, 200, 200]    39,458               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 200, 200]    [4, 96, 200, 200]    82,620               True
# ├─Downsample (down2)                                         [4, 96, 200, 200]    [4, 192, 100, 100]   --                   True
# │    └─Sequential (layers)                                   [4, 96, 200, 200]    [4, 192, 100, 100]   --                   True
# │    │    └─Conv2d (0)                                       [4, 96, 200, 200]    [4, 48, 200, 200]    41,472               True
# │    │    └─PixelUnshuffle (1)                               [4, 48, 200, 200]    [4, 192, 100, 100]   --                   --
# ├─Sequential (encoder3)                                      [4, 192, 100, 100]   [4, 192, 100, 100]   --                   True
# │    └─TransformerBlock (0)                                  [4, 192, 100, 100]   [4, 192, 100, 100]   --                   True
# │    │    └─LayerNorm (norm1)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 192, 100, 100]   [4, 192, 100, 100]   152,644              True
# │    │    └─LayerNorm (norm2)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 192, 100, 100]   [4, 192, 100, 100]   312,120              True
# │    └─TransformerBlock (1)                                  [4, 192, 100, 100]   [4, 192, 100, 100]   --                   True
# │    │    └─LayerNorm (norm1)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 192, 100, 100]   [4, 192, 100, 100]   152,644              True
# │    │    └─LayerNorm (norm2)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 192, 100, 100]   [4, 192, 100, 100]   312,120              True
# │    └─TransformerBlock (2)                                  [4, 192, 100, 100]   [4, 192, 100, 100]   --                   True
# │    │    └─LayerNorm (norm1)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 192, 100, 100]   [4, 192, 100, 100]   152,644              True
# │    │    └─LayerNorm (norm2)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 192, 100, 100]   [4, 192, 100, 100]   312,120              True
# │    └─TransformerBlock (3)                                  [4, 192, 100, 100]   [4, 192, 100, 100]   --                   True
# │    │    └─LayerNorm (norm1)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 192, 100, 100]   [4, 192, 100, 100]   152,644              True
# │    │    └─LayerNorm (norm2)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 192, 100, 100]   [4, 192, 100, 100]   312,120              True
# │    └─TransformerBlock (4)                                  [4, 192, 100, 100]   [4, 192, 100, 100]   --                   True
# │    │    └─LayerNorm (norm1)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 192, 100, 100]   [4, 192, 100, 100]   152,644              True
# │    │    └─LayerNorm (norm2)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 192, 100, 100]   [4, 192, 100, 100]   312,120              True
# │    └─TransformerBlock (5)                                  [4, 192, 100, 100]   [4, 192, 100, 100]   --                   True
# │    │    └─LayerNorm (norm1)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 192, 100, 100]   [4, 192, 100, 100]   152,644              True
# │    │    └─LayerNorm (norm2)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 192, 100, 100]   [4, 192, 100, 100]   312,120              True
# ├─Downsample (down3)                                         [4, 192, 100, 100]   [4, 384, 50, 50]     --                   True
# │    └─Sequential (layers)                                   [4, 192, 100, 100]   [4, 384, 50, 50]     --                   True
# │    │    └─Conv2d (0)                                       [4, 192, 100, 100]   [4, 96, 100, 100]    165,888              True
# │    │    └─PixelUnshuffle (1)                               [4, 96, 100, 100]    [4, 384, 50, 50]     --                   --
# ├─Sequential (latent)                                        [4, 384, 50, 50]     [4, 384, 50, 50]     --                   True
# │    └─TransformerBlock (0)                                  [4, 384, 50, 50]     [4, 384, 50, 50]     --                   True
# │    │    └─LayerNorm (norm1)                                [4, 384, 50, 50]     [4, 384, 50, 50]     384                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 384, 50, 50]     [4, 384, 50, 50]     600,200              True
# │    │    └─LayerNorm (norm2)                                [4, 384, 50, 50]     [4, 384, 50, 50]     384                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 384, 50, 50]     [4, 384, 50, 50]     1,212,948            True
# │    └─TransformerBlock (1)                                  [4, 384, 50, 50]     [4, 384, 50, 50]     --                   True
# │    │    └─LayerNorm (norm1)                                [4, 384, 50, 50]     [4, 384, 50, 50]     384                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 384, 50, 50]     [4, 384, 50, 50]     600,200              True
# │    │    └─LayerNorm (norm2)                                [4, 384, 50, 50]     [4, 384, 50, 50]     384                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 384, 50, 50]     [4, 384, 50, 50]     1,212,948            True
# │    └─TransformerBlock (2)                                  [4, 384, 50, 50]     [4, 384, 50, 50]     --                   True
# │    │    └─LayerNorm (norm1)                                [4, 384, 50, 50]     [4, 384, 50, 50]     384                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 384, 50, 50]     [4, 384, 50, 50]     600,200              True
# │    │    └─LayerNorm (norm2)                                [4, 384, 50, 50]     [4, 384, 50, 50]     384                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 384, 50, 50]     [4, 384, 50, 50]     1,212,948            True
# │    └─TransformerBlock (3)                                  [4, 384, 50, 50]     [4, 384, 50, 50]     --                   True
# │    │    └─LayerNorm (norm1)                                [4, 384, 50, 50]     [4, 384, 50, 50]     384                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 384, 50, 50]     [4, 384, 50, 50]     600,200              True
# │    │    └─LayerNorm (norm2)                                [4, 384, 50, 50]     [4, 384, 50, 50]     384                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 384, 50, 50]     [4, 384, 50, 50]     1,212,948            True
# │    └─TransformerBlock (4)                                  [4, 384, 50, 50]     [4, 384, 50, 50]     --                   True
# │    │    └─LayerNorm (norm1)                                [4, 384, 50, 50]     [4, 384, 50, 50]     384                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 384, 50, 50]     [4, 384, 50, 50]     600,200              True
# │    │    └─LayerNorm (norm2)                                [4, 384, 50, 50]     [4, 384, 50, 50]     384                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 384, 50, 50]     [4, 384, 50, 50]     1,212,948            True
# │    └─TransformerBlock (5)                                  [4, 384, 50, 50]     [4, 384, 50, 50]     --                   True
# │    │    └─LayerNorm (norm1)                                [4, 384, 50, 50]     [4, 384, 50, 50]     384                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 384, 50, 50]     [4, 384, 50, 50]     600,200              True
# │    │    └─LayerNorm (norm2)                                [4, 384, 50, 50]     [4, 384, 50, 50]     384                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 384, 50, 50]     [4, 384, 50, 50]     1,212,948            True
# │    └─TransformerBlock (6)                                  [4, 384, 50, 50]     [4, 384, 50, 50]     --                   True
# │    │    └─LayerNorm (norm1)                                [4, 384, 50, 50]     [4, 384, 50, 50]     384                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 384, 50, 50]     [4, 384, 50, 50]     600,200              True
# │    │    └─LayerNorm (norm2)                                [4, 384, 50, 50]     [4, 384, 50, 50]     384                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 384, 50, 50]     [4, 384, 50, 50]     1,212,948            True
# │    └─TransformerBlock (7)                                  [4, 384, 50, 50]     [4, 384, 50, 50]     --                   True
# │    │    └─LayerNorm (norm1)                                [4, 384, 50, 50]     [4, 384, 50, 50]     384                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 384, 50, 50]     [4, 384, 50, 50]     600,200              True
# │    │    └─LayerNorm (norm2)                                [4, 384, 50, 50]     [4, 384, 50, 50]     384                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 384, 50, 50]     [4, 384, 50, 50]     1,212,948            True
# ├─Upsample (up3)                                             [4, 384, 50, 50]     [4, 192, 100, 100]   --                   True
# │    └─Sequential (layers)                                   [4, 384, 50, 50]     [4, 192, 100, 100]   --                   True
# │    │    └─Conv2d (0)                                       [4, 384, 50, 50]     [4, 768, 50, 50]     2,654,208            True
# │    │    └─PixelShuffle (1)                                 [4, 768, 50, 50]     [4, 192, 100, 100]   --                   --
# ├─Conv2d (upsample_conv_3)                                   [4, 384, 100, 100]   [4, 192, 100, 100]   73,728               True
# ├─Sequential (decoder3)                                      [4, 192, 100, 100]   [4, 192, 100, 100]   --                   True
# │    └─TransformerBlock (0)                                  [4, 192, 100, 100]   [4, 192, 100, 100]   --                   True
# │    │    └─LayerNorm (norm1)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 192, 100, 100]   [4, 192, 100, 100]   152,644              True
# │    │    └─LayerNorm (norm2)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 192, 100, 100]   [4, 192, 100, 100]   312,120              True
# │    └─TransformerBlock (1)                                  [4, 192, 100, 100]   [4, 192, 100, 100]   --                   True
# │    │    └─LayerNorm (norm1)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 192, 100, 100]   [4, 192, 100, 100]   152,644              True
# │    │    └─LayerNorm (norm2)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 192, 100, 100]   [4, 192, 100, 100]   312,120              True
# │    └─TransformerBlock (2)                                  [4, 192, 100, 100]   [4, 192, 100, 100]   --                   True
# │    │    └─LayerNorm (norm1)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 192, 100, 100]   [4, 192, 100, 100]   152,644              True
# │    │    └─LayerNorm (norm2)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 192, 100, 100]   [4, 192, 100, 100]   312,120              True
# │    └─TransformerBlock (3)                                  [4, 192, 100, 100]   [4, 192, 100, 100]   --                   True
# │    │    └─LayerNorm (norm1)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 192, 100, 100]   [4, 192, 100, 100]   152,644              True
# │    │    └─LayerNorm (norm2)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 192, 100, 100]   [4, 192, 100, 100]   312,120              True
# │    └─TransformerBlock (4)                                  [4, 192, 100, 100]   [4, 192, 100, 100]   --                   True
# │    │    └─LayerNorm (norm1)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 192, 100, 100]   [4, 192, 100, 100]   152,644              True
# │    │    └─LayerNorm (norm2)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 192, 100, 100]   [4, 192, 100, 100]   312,120              True
# │    └─TransformerBlock (5)                                  [4, 192, 100, 100]   [4, 192, 100, 100]   --                   True
# │    │    └─LayerNorm (norm1)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 192, 100, 100]   [4, 192, 100, 100]   152,644              True
# │    │    └─LayerNorm (norm2)                                [4, 192, 100, 100]   [4, 192, 100, 100]   192                  True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 192, 100, 100]   [4, 192, 100, 100]   312,120              True
# ├─Upsample (up2)                                             [4, 192, 100, 100]   [4, 96, 200, 200]    --                   True
# │    └─Sequential (layers)                                   [4, 192, 100, 100]   [4, 96, 200, 200]    --                   True
# │    │    └─Conv2d (0)                                       [4, 192, 100, 100]   [4, 384, 100, 100]   663,552              True
# │    │    └─PixelShuffle (1)                                 [4, 384, 100, 100]   [4, 96, 200, 200]    --                   --
# ├─Conv2d (upsample_conv_2)                                   [4, 192, 200, 200]   [4, 96, 200, 200]    18,432               True
# ├─Sequential (decoder2)                                      [4, 96, 200, 200]    [4, 96, 200, 200]    --                   True
# │    └─TransformerBlock (0)                                  [4, 96, 200, 200]    [4, 96, 200, 200]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 200, 200]    [4, 96, 200, 200]    39,458               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 200, 200]    [4, 96, 200, 200]    82,620               True
# │    └─TransformerBlock (1)                                  [4, 96, 200, 200]    [4, 96, 200, 200]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 200, 200]    [4, 96, 200, 200]    39,458               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 200, 200]    [4, 96, 200, 200]    82,620               True
# │    └─TransformerBlock (2)                                  [4, 96, 200, 200]    [4, 96, 200, 200]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 200, 200]    [4, 96, 200, 200]    39,458               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 200, 200]    [4, 96, 200, 200]    82,620               True
# │    └─TransformerBlock (3)                                  [4, 96, 200, 200]    [4, 96, 200, 200]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 200, 200]    [4, 96, 200, 200]    39,458               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 200, 200]    [4, 96, 200, 200]    82,620               True
# │    └─TransformerBlock (4)                                  [4, 96, 200, 200]    [4, 96, 200, 200]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 200, 200]    [4, 96, 200, 200]    39,458               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 200, 200]    [4, 96, 200, 200]    82,620               True
# │    └─TransformerBlock (5)                                  [4, 96, 200, 200]    [4, 96, 200, 200]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 200, 200]    [4, 96, 200, 200]    39,458               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 200, 200]    [4, 96, 200, 200]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 200, 200]    [4, 96, 200, 200]    82,620               True
# ├─Upsample (up1)                                             [4, 96, 200, 200]    [4, 48, 400, 400]    --                   True
# │    └─Sequential (layers)                                   [4, 96, 200, 200]    [4, 48, 400, 400]    --                   True
# │    │    └─Conv2d (0)                                       [4, 96, 200, 200]    [4, 192, 200, 200]   165,888              True
# │    │    └─PixelShuffle (1)                                 [4, 192, 200, 200]   [4, 48, 400, 400]    --                   --
# ├─Sequential (decoder1)                                      [4, 96, 400, 400]    [4, 96, 400, 400]    --                   True
# │    └─TransformerBlock (0)                                  [4, 96, 400, 400]    [4, 96, 400, 400]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 400, 400]    [4, 96, 400, 400]    39,457               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 400, 400]    [4, 96, 400, 400]    82,620               True
# │    └─TransformerBlock (1)                                  [4, 96, 400, 400]    [4, 96, 400, 400]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 400, 400]    [4, 96, 400, 400]    39,457               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 400, 400]    [4, 96, 400, 400]    82,620               True
# │    └─TransformerBlock (2)                                  [4, 96, 400, 400]    [4, 96, 400, 400]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 400, 400]    [4, 96, 400, 400]    39,457               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 400, 400]    [4, 96, 400, 400]    82,620               True
# │    └─TransformerBlock (3)                                  [4, 96, 400, 400]    [4, 96, 400, 400]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 400, 400]    [4, 96, 400, 400]    39,457               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 400, 400]    [4, 96, 400, 400]    82,620               True
# │    └─TransformerBlock (4)                                  [4, 96, 400, 400]    [4, 96, 400, 400]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 400, 400]    [4, 96, 400, 400]    39,457               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 400, 400]    [4, 96, 400, 400]    82,620               True
# │    └─TransformerBlock (5)                                  [4, 96, 400, 400]    [4, 96, 400, 400]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 400, 400]    [4, 96, 400, 400]    39,457               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 400, 400]    [4, 96, 400, 400]    82,620               True
# ├─Sequential (refinement)                                    [4, 96, 400, 400]    [4, 96, 400, 400]    --                   True
# │    └─TransformerBlock (0)                                  [4, 96, 400, 400]    [4, 96, 400, 400]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 400, 400]    [4, 96, 400, 400]    39,457               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 400, 400]    [4, 96, 400, 400]    82,620               True
# │    └─TransformerBlock (1)                                  [4, 96, 400, 400]    [4, 96, 400, 400]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 400, 400]    [4, 96, 400, 400]    39,457               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 400, 400]    [4, 96, 400, 400]    82,620               True
# │    └─TransformerBlock (2)                                  [4, 96, 400, 400]    [4, 96, 400, 400]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 400, 400]    [4, 96, 400, 400]    39,457               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 400, 400]    [4, 96, 400, 400]    82,620               True
# │    └─TransformerBlock (3)                                  [4, 96, 400, 400]    [4, 96, 400, 400]    --                   True
# │    │    └─LayerNorm (norm1)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─MultiDConvHeadTransposedAttention (attn)         [4, 96, 400, 400]    [4, 96, 400, 400]    39,457               True
# │    │    └─LayerNorm (norm2)                                [4, 96, 400, 400]    [4, 96, 400, 400]    96                   True
# │    │    └─GatedDConvFeedForwardNetwork (ffn)               [4, 96, 400, 400]    [4, 96, 400, 400]    82,620               True
# ├─Conv2d (final_conv)                                        [4, 96, 400, 400]    [4, 1, 400, 400]     864                  True
# ============================================================================================================================================
# Total params: 26,711,742
# Trainable params: 26,711,742
# Non-trainable params: 0
# Total mult-adds (Units.TERABYTES): 1.58
# ============================================================================================================================================
# Input size (MB): 2.56
# Forward/backward pass size (MB): 173381.12
# Params size (MB): 106.85
# Estimated Total Size (MB): 173490.53
# ============================================================================================================================================
